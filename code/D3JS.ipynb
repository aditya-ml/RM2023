# %%
s = """link,model,role,access
link1,model1,role1,true""";

# %%
s
# Out:
# 'link,model,role,access\nlink1,model1,role1,true'

# %%
lines = str.split('\n');
obj = {};
# // Ignore the first line as it contains only the header info.
for i in range(1,len(lines),1):
  lineItems = lines[i].split(',');
  link = lineItems[0];
  model = lineItems[1];
  role = lineItems[2];
  roleValue = lineItems[3];
  
  if link not in obj:
    obj[i][link] = lineItems[0];

# %%
obj
# Out:
# {}

# %%
import pandas as pd
df = pd.read_csv('/content/public health agencies rules.csv')

# %%
df.shape[0]
# Out:
# 6151

# %%
df = df.drop_duplicates()

# %%
df[:101]
# Out:
#     antecedents consequents
# 0         event      advers
# 1        advers       event
# 2        report      advers
# 3        advers      report
# 4       johnson         amp
# ..          ...         ...
# 242       pleas       offic
# 243       pleas       local
# 251       reach          us
# 275        team          us
# 374       pleas       reach
#
# [101 rows x 2 columns]

# %%
data=[]

# %%
for index, row in df.iterrows():
  source="pharma."+row['antecedents']
  if(next((item for item in data if item["name"] == source), None)):
    item=next(item for item in data if item["name"] == source)
    temp_l=item["imports"]
    temp_l.append("pharma."+row['consequents'])
    item["imports"]=temp_l
    continue

  target="pharma."+row['consequents']
  l=[]
  l.append(target)
  dictionary = {"name": source, "imports": l}
  data.append(dictionary)

print(data)
# Out:
# [{'name': 'pharma.get', 'imports': ['pharma.covid', 'pharma.covid', 'pharma.learn', 'pharma.covid', 'pharma.lt', 'pharma.vaccin', 'pharma.covid', 'pharma.learn', 'pharma.lt', 'pharma.vaccin', 'pharma.learn', 'pharma.vaccin', 'pharma.lt', 'pharma.covid', 'pharma.learn', 'pharma.lt', 'pharma.learn', 'pharma.covid', 'pharma.lt', 'pharma.covid', 'pharma.lt', 'pharma.learn', 'pharma.vaccin', 'pharma.covid', 'pharma.learn', 'pharma.covid', 'pharma.vaccin', 'pharma.learn', 'pharma.vaccin', 'pharma.learn', 'pharma.covid', 'pharma.vaccin', 'pharma.covid', 'pharma.lt', 'pharma.covid', 'pharma.vaccin', 'pharma.lt', 'pharma.vaccin', 'pharma.lt', 'pharma.covid', 'pharma.vaccin', 'pharma.learn', 'pharma.lt', 'pharma.learn', 'pharma.vaccin', 'pharma.lt', 'pharma.vaccin', 'pharma.lt', 'pharma.learn', 'pharma.covid', 'pharma.vaccin', 'pharma.lt', 'pharma.learn', 'pharma.covid', 'pharma.vaccin', 'pharma.lt', 'pharma.covid', 'pharma.lt', 'pharma.vaccin', 'pharma.learn', 'pharma.covid', 'pharma.learn', 
# ...

# %%
len(data)
# Out:
# 15

# %%
for index in range(len(data)):
    for key in data[index]:
        # print(data[index][key])
        for val in data[index][key]:
          if(next((item for item in data if (item["name"] == ("pharma."+val) or item["name"]==val)), None)):
            continue
          if("pharma." in val):
            source=val
          else:
            source = "pharma."+val
          print(source)
          target=[]
          data.append({"name": source, "imports": target})
# Out:
# pharma.p
# pharma.h
# pharma.a
# pharma.r
# pharma.m
# pharma..
# pharma.g
# pharma.e
# pharma.t
# pharma.l
# pharma.n
# pharma.o
# pharma.c
# pharma.v
# pharma.i
# pharma.s
# pharma.u
# pharma.k
# pharma.b
# pharma.y
# pharma.d

# %% [markdown]
# [{
#   "name": "iit.pub1",
#   "imports": ["iit.pub3"]
# }, {
#   "name": "iit.pub2",
#   "imports": ["iit.pub1"]
# }, {
#   "name": "iit.pub3",
#   "imports": ["iit.pub2"]
# }]
#
# ```
# # This is formatted as code
# ```

# %%
import json
omg=json.dumps(data)

# %%
with open('data.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# [{"name":"pharma.event", "imports": ["pharma.advers"]}, {"name": "pharma.advers", "imports": ["pharma.event"]}, {"name": "pharma.report", "imports": ["pharma.advers"]}, {"name": "pharma.advers", "imports": ["pharma.report"]}, {"name": "pharma.johnson", "imports": ["pharma.amp"]}, {"name": "pharma.answer", "imports": ["pharma.question"]}, {"name": "pharma.around", "imports": ["pharma.world"]}, {"name": "pharma.author", "imports": ["pharma.covid"]}, {"name": "pharma.best", "imports": ["pharma.contact"]}, {"name": "pharma.center", "imports": ["pharma.call"]}, {"name": "pharma.call", "imports": ["pharma.pleas"]}, {"name": "pharma.call", "imports": ["pharma.vaccin"]}, {"name": "pharma.center", "imports": ["pharma.vaccin"]}, {"name": "pharma.chief", "imports": ["pharma.offic"]}, {"name": "pharma.click", "imports": ["pharma.contact"]}, {"name": "pharma.click", "imports": ["pharma.offic"]}, {"name": "pharma.trial", "imports": ["pharma.clinic"]}, {"name": "pharma.clinic", "imports": ["pharma.trial"]}, {"name": "pharma.info", "imports": ["pharma.contact"]}, {"name": "pharma.inform", "imports": ["pharma.contact"]}, {"name": "pharma.local", "imports": ["pharma.contact"]}, {"name": "pharma.offic", "imports": ["pharma.contact"]}, {"name": "pharma.phone", "imports": ["pharma.contact"]}, {"name": "pharma.contact", "imports": ["pharma.pleas"]}, {"name": "pharma.pleas", "imports": ["pharma.contact"]}, {"name": "pharma.reach", "imports": ["pharma.contact"]}, {"name": "pharma.contact", "imports": ["pharma.thank"]}, {"name": "pharma.wed", "imports": ["pharma.contact"]}, {"name": "pharma.pandem", "imports": ["pharma.covid"]}, {"name": "pharma.vaccin", "imports": ["pharma.covid"]}, {"name": "pharma.side", "imports": ["pharma.effect"]}, {"name": "pharma.effect", "imports": ["pharma.side"]}, {"name": "pharma.effect", "imports": ["pharma.vaccin"]}, {"name": "pharma.report", "imports": ["pharma.event"]}, {"name": "pharma.event", "imports": ["pharma.report"]}, {"name": "pharma.fdacdc", "imports": ["pharma.report"]}, {"name": "pharma.investor", "imports": ["pharma.media"]}, {"name": "pharma.investor", "imports": ["pharma.news"]}, {"name": "pharma.news", "imports": ["pharma.investor"]}, {"name": "pharma.wed", "imports": ["pharma.like"]}, {"name": "pharma.local", "imports": ["pharma.offic"]}, {"name": "pharma.offic", "imports": ["pharma.local"]}, {"name": "pharma.phone", "imports": ["pharma.local"]}, {"name": "pharma.news", "imports": ["pharma.media"]}, {"name": "pharma.social", "imports": ["pharma.media"]}, {"name": "pharma.phone", "imports": ["pharma.offic"]}, {"name": "pharma.phone", "imports": ["pharma.pleas"]}, {"name": "pharma.reach", "imports": ["pharma.pleas"]}, {"name": "pharma.pleas", "imports": ["pharma.thank"]}, {"name": "pharma.wed", "imports": ["pharma.pleas"]}, {"name": "pharma.reach", "imports": ["pharma.thank"]}, {"name": "pharma.system", "imports": ["pharma.vaccin"]}, {"name": "pharma.team", "imports": ["pharma.thank"]}, {"name": "pharma.wed", "imports": ["pharma.thank"]}, {"name": "pharma.wed", "imports": ["pharma.us"]}, {"name": "pharma.amp", "imports": ["pharma.covid"]}, {"name": "pharma.amp", "imports": ["pharma.vaccin"]}, {"name": "pharma.covid", "imports": ["pharma.vaccin"]}, {"name": "pharma.thank", "imports": ["pharma.pleas"]}, {"name": "pharma.call", "imports": ["pharma.thank"]}, {"name": "pharma.us", "imports": ["pharma.pleas"]}, {"name": "pharma.call", "imports": ["pharma.us"]}, {"name": "pharma.pleas", "imports": ["pharma.us"]}, {"name": "pharma.vaccin", "imports": ["pharma.pleas"]}, {"name": "pharma.vaccin", "imports": ["pharma.call"]}, {"name": "pharma.pleas", "imports": ["pharma.call"]}, {"name": "pharma.pleas", "imports": ["pharma.vaccin"]}, {"name": "pharma.us", "imports": ["pharma.thank"]}, {"name": "pharma.thank", "imports": ["pharma.us"]}, {"name": "pharma.thank", "imports": ["pharma.call"]}, {"name": "pharma.thank", "imports": ["pharma.vaccin"]}, {"name": "pharma.vaccin", "imports": ["pharma.thank"]}, {"name": "pharma.contact", "imports": ["pharma.offic"]}, {"name": "pharma.inform", "imports": ["pharma.local"]}, {"name": "pharma.contact", "imports": ["pharma.local"]}, {"name": "pharma.inform", "imports": ["pharma.offic"]}, {"name": "pharma.like", "imports": ["pharma.pleas"]}, {"name": "pharma.like", "imports": ["pharma.contact"]}, {"name": "pharma.thank", "imports": ["pharma.contact"]}, {"name": "pharma.like", "imports": ["pharma.thank"]}, {"name": "pharma.us", "imports": ["pharma.contact"]}, {"name": "pharma.thank", "imports": ["pharma.reach"]}, {"name": "pharma.contact", "imports": ["pharma.reach"]}, {"name": "pharma.team", "imports": ["pharma.contact"]}, {"name": "pharma.contact", "imports": ["pharma.us"]}, {"name": "pharma.learn", "imports": ["pharma.covid"]}, {"name": "pharma.media", "imports": ["pharma.investor"]}, {"name": "pharma.media", "imports": ["pharma.news"]}, {"name": "pharma.like", "imports": ["pharma.us"]}, {"name": "pharma.like", "imports": ["pharma.wed"]}, {"name": "pharma.pleas", "imports": ["pharma.wed"]}, {"name": "pharma.pleas", "imports": ["pharma.like"]}, {"name": "pharma.thank", "imports": ["pharma.wed"]}, {"name": "pharma.thank", "imports": ["pharma.like"]}, {"name": "pharma.us", "imports": ["pharma.wed"]}, {"name": "pharma.us", "imports": ["pharma.like"]}, {"name": "pharma.pleas", "imports": ["pharma.offic"]}, {"name": "pharma.pleas", "imports": ["pharma.local"]}, {"name": "pharma.reach", "imports": ["pharma.us"]}, {"name": "pharma.team", "imports": ["pharma.us"]}, {"name": "pharma.pleas", "imports": ["pharma.reach"]}]

# %%
# !pip install matplotlib --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.2 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 960 kB 34.2 MB/s
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ...

# %%
import pandas as pd
matrix_df=pd.read_csv('/content/Support vs Confidence for pharma companies.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-90f8eaacae1c> in <module>
#       1 import pandas as pd
# ----> 2 matrix_df=pd.read_csv('/content/Support vs Confidence for pharma companies.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import re, seaborn as sns
import numpy as np

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# generate data
n = 200
# x = np.random.uniform(1, 20, size=n)
# y = np.random.uniform(1, 100, size=n)
# z = np.random.uniform(1, 100, size=n)
z = matrix_df['Count of rules']
x = matrix_df['Threshold Confidence']
y = matrix_df['Threshold Support']

# axes instance
fig = plt.figure(figsize=(8,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=x, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Min confidence')
ax.set_ylabel('Min support')
ax.set_zlabel('Count of rules')
ax.set_title('Min confidence vs Min support')

# First remove fill
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

# Now set color to white (or whatever is "invisible")
ax.xaxis.pane.set_edgecolor('w')
ax.yaxis.pane.set_edgecolor('w')
ax.zaxis.pane.set_edgecolor('w')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
plt.savefig("scatter_hue", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3ca835363ec0> in <module>
#      11 # y = np.random.uniform(1, 100, size=n)
#      12 # z = np.random.uniform(1, 100, size=n)
# ---> 13 z = matrix_df['Count of rules']
#      14 x = matrix_df['Threshold Confidence']
#      15 y = matrix_df['Threshold Support']
#
# NameError: name 'matrix_df' is not defined

# %%
save_df=pd.read_csv('/content/final public health agencies.csv')

counter_0to20=0
counter_21to40=0
counter_41to60=0
counter_61to80=0
counter_81to100=0

print(save_df['Tweet ID (iloc)'].max())
lim=save_df['Tweet ID (iloc)'].max()
lim=lim/5
for index, row in save_df.iterrows():
  if(row['Tweet ID (iloc)'])<=lim:
    counter_0to20=counter_0to20+1
  elif(row['Tweet ID (iloc)'])<=2*lim:
    counter_21to40=counter_21to40+1
  elif(row['Tweet ID (iloc)'])<=3*lim:
    counter_41to60=counter_41to60+1
  elif(row['Tweet ID (iloc)'])<=4*lim:
    counter_61to80=counter_61to80+1
  else: 
    counter_81to100=counter_81to100+1
# Out:
# 6547

# %%
print(counter_0to20, " ", counter_21to40, " ", counter_41to60, " ", counter_61to80, " ", counter_81to100)

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
lim = ['500', '1000', '1500', '2000', '2500']
val = [counter_0to20,counter_21to40,counter_41to60,counter_61to80,counter_81to100]
ax.bar(lim,val, color = 'orange')
plt.show()
# Out:
# 2232   2157   1650   1246   938

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
df=pd.read_csv('/content/plot_data.csv')
sns.histplot(data=df)

# %%
data = df.set_index('Percentile').unstack().reset_index()
data.columns = ['Twitter Group','Percentile', 'Frequency of association rules']

sns.set(style="white")
g = sns.factorplot(x='Twitter Group'
                   ,y= 'Frequency of association rules'
                   ,hue='Percentile'
                   ,data=data
                   ,kind='bar'
                   ,aspect=2
                   )
g.set_xticklabels(rotation=0);
